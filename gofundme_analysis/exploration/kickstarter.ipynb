# %% [markdown]
# ## Kickstarter Project Exploration
#
# Explore cancer projects from Kickstarter

# %%
import os.path as op

import pandas as pd
import numpy as np
import json

import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_columns = 100
# %config InlineBackend.figure_format = 'retina'

# %%
DATA_PROCESSED = '../data/processed'

# %%
data = pd.read_csv(op.join(DATA_PROCESSED, 'cancer_projects_full.csv'))

data.sample(3)
# Out:
#              id                                               name  \
# 160   243027313  Team of women make film based on true story ca...
# 165  1253964998                    The Materiality of Impermanence
# 90   1419934045                               Twice Two Makes Four
#
#                                                  blurb     created  \
# 160  With "Maria my love" tattooed on her wrist, ac...  1251726646
# 165  An evening-length dance piece inspired by my j...  1286766140
# 90   A story about the Hawthorne's, a couple strugg...  1326231505
#
#        launched    deadline   goal  spotlight  staff_pick  status  \
# 160  1252507879  1257094740  10000       True       False       1
# 165  1286937119  1292124719   3000       True       False       1
# 90   1327388690  1329980690  20000       True       False       1
#
#      status_changed_at  backers  usd_pledged   pledged currency  \
# 160         1257094810       96     10600.22  10600.22      USD
# 165         1292125510       67      4891.00   4891.00      USD
# 90          1329980690       73     20635.00  20635.00      USD
#
#     current_currency       category geo_country geo_state geo_type  \
# 160              USD   film & video          US        NY     Town
# 165              USD  dance_theater          US        TX     Town
# 90               USD   film & video          US        MA     Town
#
#                                                    url  \
# 160  https://www.kickstarter.com/projects/jasminemc...
# 165  https://www.kickstarter.com/projects/205522799...
# 90   https://www.kickstarter.com/projects/twicetwom...
#
#                                                   text  mean_donation  \
# 160  We are a team of women filmmakers whose first ...     110.418958
# 165  My life changed forever on January 8th, 2010. ...      73.000000
# 90   *The footage above is only meant to provide a ...     282.671233
#
#      text_length_words  text_length_sentences  pledged_to_goal  duration  \
# 160               1386                     54         1.060022   4586861
# 165                392                     19         1.630333   5187600
# 90                 369                     19         1.031750   2592000
#
#      duration_float  month  day_of_week  year  from_US  from_Town  \
# 160       53.088669      9            2  2009        1          1
# 165       60.041667     10            2  2010        1          1
# 90        30.000000      1            1  2012        1          1
#
#      blurb_length_words  battle_metaphor  journey_metaphor  battle_uniques  \
# 160                  27                0                 0               0
# 165                  14                0                 0               0
# 90                   19                0                 0               0
#
#      journey_uniques  battle_salience  journey_salience  battle_productivity  \
# 160                0              0.0               0.0                  0.0
# 165                0              0.0               0.0                  0.0
# 90                 0              0.0               0.0                  0.0
#
#      journey_productivity  dominant_battle  dominant_journey  dominant_both  \
# 160                   0.0                0                 0              0
# 165                   0.0                0                 0              0
# 90                    0.0                0                 0              0
#
#      dominant_neither dominant
# 160                 1  Neither
# 165                 1  Neither
# 90                  1  Neither

# %%
data.shape
# Out:
# (409, 47)

# %% [markdown]
# Clean out projects not classified as Success or Fail

# %%
cnt = data['status'].value_counts()
plt.subplots(figsize=(8,4))
sns.barplot(cnt.index, cnt.values)
plt.xticks(rotation=20);

# %% [markdown]
# ### Country of Origin

# %%
cnt = data['geo_country'].value_counts()
plt.subplots(figsize=(12,6))
sns.barplot(cnt.index, cnt.values / len(data))
plt.xticks(rotation=20)
plt.grid(alpha=0.25, axis='y')
plt.title('Project Country of Origin Density');

# %% [markdown]
# ### Parent Project Categories

# %%
cnt = data['category'].value_counts()
plt.subplots(figsize=(12,6))
sns.barplot(cnt.index, cnt.values / len(data))
plt.xticks(rotation=20)
plt.grid(alpha=0.25, axis='y')
plt.title('Parent Project Category Density');

# %% [markdown]
# ### Geo Types

# %%
cnt = data['geo_type'].value_counts()
sns.barplot(cnt.index, cnt.values / len(data))
plt.xticks(rotation=20)
plt.grid(alpha=0.25, axis='y')
plt.title('Project Geographical Type Density');

# %% [markdown]
# ### Duration

# %%
plt.subplots(figsize=(12,5))
td = pd.Series([ pd.Timedelta(days=i) for i in range(0, 92, 7)])
r = pd.cut(pd.TimedeltaIndex(data['duration'], unit='s').to_series(), td, labels=False).value_counts()
g = sns.barplot(r.index, r.values / len(data))
g.set_xticklabels([f'>{int(w)} weeks' for w in td.dt.days / 7])
plt.grid(alpha=0.25, axis='y')
plt.title('Project Duration Density');

# %% [markdown]
# ### Launch Month Density

# %%
vc = data['month'].value_counts() / len(data)
sns.barplot(vc.index, vc.values)
plt.grid(alpha=0.25, axis='y')
plt.title('Monthly Project Density');

# %% [markdown]
# ## Dependent Variables to Focus on
#
#  - Pledged to Goal
#   - Focused mainly around 0 and 1-2, with some outliers after 2
#  - Mean Donation
#   - Looks like some parameterization of a gamma distribution
#  - Status (success or failure)
#   - Logistic Regression
#  - Backers
#   - Long tailed Poisson
#
# ### Examine Outliers

# %%
sns.distplot(data['mean_donation'])
plt.xlim([-10, 800]);

# %%
data.loc[data['mean_donation'] > 300]
# Out:
#              id                                            name  \
# 35    359128200  Stöd berättelserna om cancer som hjälper andra
# 306  1951561426   KNOCKING ON HEAVENS DOOR: A FILM NOIR FEATURE
# 364  1201395817                                       ChemoHead
#
#                                                  blurb     created  \
# 35   Cancerpodden - Anna Benson möter läkare och fo...  1497801645
# 306  Alex is a black ops soldier. He possesses the ...  1463687261
# 364  "ChemoHead" is a film about the relationship b...  1421369959
#
#        launched    deadline   goal  spotlight  staff_pick  status  \
# 35   1497990193  1503174193  50000      False       False       0
# 306  1466124952  1471308952  25000       True       False       1
# 364  1422081391  1424673391  55000      False       False       0
#
#      status_changed_at  backers   usd_pledged  pledged currency  \
# 35          1503174193        1    344.703270   3000.0      SEK
# 306         1471308952       29  19704.445046  25329.0      CAD
# 364         1424673392       10   5189.000000   5189.0      USD
#
#     current_currency      category geo_country  geo_state geo_type  \
# 35               USD    publishing          SE  Stockholm     Town
# 306              USD  film & video          CA         ON     Town
# 364              USD  film & video          US         MO     Town
#
#                                                    url  \
# 35   https://www.kickstarter.com/projects/265847814...
# 306  https://www.kickstarter.com/projects/777006802...
# 364  https://www.kickstarter.com/projects/206358583...
#
#                                                   text  mean_donation  \
# 35   Att producera Cancerpodden kostar 3000 kronor ...     344.703270
# 306  Alex Rowe (Jeff Ellenberger) is a black ops so...     679.463622
# 364  If that word doesn't scare you now, it will so...     518.900000
#
#      text_length_words  text_length_sentences  pledged_to_goal  duration  \
# 35                 346                     21         0.060000   5184000
# 306               1418                     61         1.013160   5184000
# 364                806                     51         0.094345   2592000
#
#      duration_float  month  day_of_week  year  from_US  from_Town  \
# 35             60.0      6            1  2017        0          1
# 306            60.0      6            4  2016        0          1
# 364            30.0      1            5  2015        1          1
#
#      blurb_length_words  battle_metaphor  journey_metaphor  battle_uniques  \
# 35                   22                0                 0               0
# 306                  24                0                 0               0
# 364                  13                1                 0               1
#
#      journey_uniques  battle_salience  journey_salience  battle_productivity  \
# 35                 0         0.000000               0.0                  0.0
# 306                0         0.000000               0.0                  0.0
# 364                0         0.001241               0.0                  1.0
#
#      journey_productivity  dominant_battle  dominant_journey  dominant_both  \
# 35                    0.0                0                 0              0
# 306                   0.0                0                 0              0
# 364                   0.0                1                 0              0
#
#      dominant_neither dominant
# 35                  1  Neither
# 306                 1  Neither
# 364                 0   Battle

# %% [markdown]
# There are three projects with mean donation above $300 per donor. Except for maybe the first one there, they all look legit. The second one was even featured with a Spotlight position.

# %%
sns.distplot(data['pledged_to_goal'])
plt.xlim([-0.2, 10.5])
# Out:
# (-0.2, 10.5)

# %%
data.loc[data['pledged_to_goal'] > 4]
# Out:
#              id                                               name  \
# 141  1707749521    For the Dexterous Colourist (Cancer Fundraiser)
# 226   425105602  Comedian Dying of Cancer Hopes to Make a Stand...
# 304  1579740363  Poems from my year of breast cancer- time to p...
#
#                                                  blurb     created  \
# 141  Ingrid is offering adult colouring pages to as...  1471714584
# 226  Quincy Jones, stand-up comic, has one dying wi...  1455559253
# 304  Poetry got me through this year of cancer trea...  1531089402
#
#        launched    deadline  goal  spotlight  staff_pick  status  \
# 141  1471913999  1473209999   500       True       False       1
# 226  1456032931  1458345600  4985       True        True       1
# 304  1531828656  1534420656  1500       True        True       1
#
#      status_changed_at  backers   usd_pledged   pledged currency  \
# 141         1473209999       41   1596.450816   2054.00      CAD
# 226         1458345600     1204  50273.280000  50273.28      USD
# 304         1534420657      321  13311.000000  13311.00      USD
#
#     current_currency      category geo_country geo_state geo_type  \
# 141              USD           art          CA        NS     Town
# 226              USD  film & video          US        CA     Town
# 304              USD    publishing          US        TN     Town
#
#                                                    url  \
# 141  https://www.kickstarter.com/projects/79797116/...
# 226  https://www.kickstarter.com/projects/204327507...
# 304  https://www.kickstarter.com/projects/177890768...
#
#                                                   text  mean_donation  \
# 141  IMPORTANT NOTE: This Kickstarter Project is fo...      38.937825
# 226  Two years ago I hurried home from my meaningle...      41.755216
# 304  Trauma is pre-verbal, according to The Body Ke...      41.467290
#
#      text_length_words  text_length_sentences  pledged_to_goal  duration  \
# 141                277                     16         4.108000   1296000
# 226               1591                    104        10.084911   2312669
# 304                955                     56         8.874000   2592000
#
#      duration_float  month  day_of_week  year  from_US  from_Town  \
# 141       15.000000      8            1  2016        0          1
# 226       26.767002      2            6  2016        1          1
# 304       30.000000      7            1  2018        1          1
#
#      blurb_length_words  battle_metaphor  journey_metaphor  battle_uniques  \
# 141                  19                1                 0               1
# 226                  24                1                 0               1
# 304                  19                0                 0               0
#
#      journey_uniques  battle_salience  journey_salience  battle_productivity  \
# 141                0         0.003610               0.0                  1.0
# 226                0         0.000629               0.0                  1.0
# 304                0         0.000000               0.0                  0.0
#
#      journey_productivity  dominant_battle  dominant_journey  dominant_both  \
# 141                   0.0                1                 0              0
# 226                   0.0                1                 0              0
# 304                   0.0                0                 0              0
#
#      dominant_neither dominant
# 141                 0   Battle
# 226                 0   Battle
# 304                 1  Neither

# %% [markdown]
# All look pretty legit.
#
# Confirming the pledged to goal ratios and mean donations for projects that succeed and fail:

# %%
print(data.groupby('status')['pledged'].sum() / data.groupby('status')['goal'].sum())
print(data.groupby('status')['usd_pledged'].sum() / data.groupby('status')['backers'].sum())
# Out:
# status
# 0    0.016477
# 1    1.264030
# dtype: float64
# status
# 0    60.164326
# 1    75.495179
# dtype: float64

# %% [markdown]
# Overlapping histograms of the text length in words for failing and succeeding projects. This later comes up as important effect in the model.

# %%
sns.distplot(data.loc[data['status'] == 0, 'text_length_words'], label='Failure')
g = sns.distplot(data.loc[data['status'] == 1, 'text_length_words'], label='Success')
g.axvline(data.loc[data['status'] == 1, 'text_length_words'].mean(), c='orange', linestyle='--')
g.axvline(data.loc[data['status'] == 0, 'text_length_words'].mean(), c='blue', linestyle='--')
plt.legend();

# %% [markdown]
# Comparing goal amounts between fail/success. Looking at mean, which is skewed a bit, so also median.

# %%
data.groupby('status')['goal'].mean(), data.groupby('status')['goal'].quantile(0.5)
# Out:
# (status
#  0    32721.935000
#  1     9268.755981
#  Name: goal, dtype: float64, status
#  0    6000.0
#  1    5000.0
#  Name: goal, dtype: float64)

# %%
data_post2010 = data.loc[data['year'] > 2010, :]

# %%
print(data_post2010.groupby('year')['pledged'].sum() / data_post2010.groupby('year')['goal'].sum())
print(data_post2010.groupby('year')['usd_pledged'].sum() / data_post2010.groupby('year')['backers'].sum())
# Out:
# year
# 2011    0.968363
# 2012    1.201871
# 2013    0.849756
# 2014    0.189243
# 2015    0.153775
# 2016    0.270711
# 2017    0.172016
# 2018    0.603106
# dtype: float64
# year
# 2011     77.620207
# 2012     70.230593
# 2013     79.961930
# 2014     55.465974
# 2015     97.261034
# 2016     73.386609
# 2017     86.274929
# 2018    101.655851
# dtype: float64

# %%
sns.distplot(data['backers'])

# %%
data.loc[data['backers'] > 1000]
# Out:
#             id                                               name  \
# 218  981149095           "Be Here Now" – The Andy Whitfield Story
# 226  425105602  Comedian Dying of Cancer Hopes to Make a Stand...
# 335  298763592                                That Dragon, Cancer
#
#                                                  blurb     created  \
# 218  Inspiring documentary about Andy Whitfield who...  1336147853
# 226  Quincy Jones, stand-up comic, has one dying wi...  1455559253
# 335  A videogame developer's love letter to his son...  1413595915
#
#        launched    deadline    goal  spotlight  staff_pick  status  \
# 218  1339185851  1343073851  200000       True       False       1
# 226  1456032931  1458345600    4985       True        True       1
# 335  1415812788  1418436000   85000       True        True       1
#
#      status_changed_at  backers  usd_pledged    pledged currency  \
# 218         1343073852     5265    302810.91  302810.91      USD
# 226         1458345600     1204     50273.28   50273.28      USD
# 335         1418436012     3687    104491.16  104491.16      USD
#
#     current_currency      category geo_country geo_state geo_type  \
# 218              USD  film & video          AU       NSW     Town
# 226              USD  film & video          US        CA     Town
# 335              USD  crafts_games          US        IA     Town
#
#                                                    url  \
# 218  https://www.kickstarter.com/projects/426354716...
# 226  https://www.kickstarter.com/projects/204327507...
# 335  https://www.kickstarter.com/projects/numinousg...
#
#                                                   text  mean_donation  \
# 218  There is Now Less Than 3 Hours to go of the Ca...      57.513943
# 226  Two years ago I hurried home from my meaningle...      41.755216
# 335  "A poetic, emotionally intense story of love i...      28.340429
#
#      text_length_words  text_length_sentences  pledged_to_goal  duration  \
# 218               1957                     46         1.514055   3888000
# 226               1591                    104        10.084911   2312669
# 335                441                     19         1.229308   2623212
#
#      duration_float  month  day_of_week  year  from_US  from_Town  \
# 218       45.000000      6            4  2012        0          1
# 226       26.767002      2            6  2016        1          1
# 335       30.361250     11            2  2014        1          1
#
#      blurb_length_words  battle_metaphor  journey_metaphor  battle_uniques  \
# 218                  21                5                 0               4
# 226                  24                1                 0               1
# 335                  25                2                 0               2
#
#      journey_uniques  battle_salience  journey_salience  battle_productivity  \
# 218                0         0.002555               0.0                  0.8
# 226                0         0.000629               0.0                  1.0
# 335                0         0.004535               0.0                  1.0
#
#      journey_productivity  dominant_battle  dominant_journey  dominant_both  \
# 218                   0.0                1                 0              0
# 226                   0.0                1                 0              0
# 335                   0.0                1                 0              0
#
#      dominant_neither dominant
# 218                 0   Battle
# 226                 0   Battle
# 335                 0   Battle

# %% [markdown]
# All three seem legit, therefore it would be artificially limiting the data to cut these out. Note that only about once every two years is there a project with more than 1,000 backers.
